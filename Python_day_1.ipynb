# %%
population= 38163839673
print(population)
# Out:
# 38163839673

# %%
unemployment_rate = 36
print(unemployment_rate)
# Out:
# 36

# %%
years_until_2030 =2030-2025
print(years_until_2030)
# Out:
# 5

# %%
type(years_until_2030)
# Out:
# int

# %%
inflation_rate = 5.42
gpd_growth = 6.3
print("the inflation rate is =", inflation_rate)
# Out:
# the inflation rate is = 5.42

# %% [markdown]
# 3. string
# text

# %%
name = "Tenzin"
print(name)
print("her name is ", name)
# Out:
# Tenzin
# her name is  Tenzin

# %%
type(name)
# Out:
# str

# %% [markdown]
# List
# List of values seperated by commas

# %%
foods = ["pizza","burger", 20]
print(foods)
# Out:
# ['pizza', 'burger', 20]

# %%
type(foods)
# Out:
# list

# %%
numbers = [346, 420, 123, 25, 503, 96]
print(numbers)
numbers.append(69)
print(numbers)
numbers.pop(2)
print(numbers)
numbers.pop()
print(numbers)
# Out:
# [346, 420, 123, 25, 503, 96]
# [346, 420, 123, 25, 503, 96, 69]
# [346, 420, 25, 503, 96, 69]
# [346, 420, 25, 503, 96]

# %%
print(sorted(numbers))
# Out:
# [25, 96, 123, 346, 420, 503]

# %% [markdown]
# Tuple

# %%
number = (1, 6, "hi", 3.7)
print(number)
# Out:
# (1, 6, 'hi', 3.7)

# %%
type(number)
# Out:
# tuple
